# %%
# !pip install langchain #The main library to use langchain components
# !pip install langchain_google_genai #It is langchain package to connect with gemini models through langchain.
# !pip install langchain_classic
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (1.2.10)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.2.12)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.0.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.12.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.8->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.8->langchain) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.8->langchain) (0.3.5)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.8->langchain) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.4)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.5.0)
# Requirement already satisfied: langchain_google_genai in /usr/local/lib/python3.12/dist-packages (4.2.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain_google_genai) (1.2.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.56.0 in /usr/local/lib/python3.12/dist-packages (from langchain_google_genai) (1.63.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.5 in /usr/local/lib/python3.12/dist-packages (from langchain_google_genai) (1.2.12)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain_google_genai) (2.12.3)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (4.12.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in /usr/local/lib/python3.12/dist-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (2.47.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (9.1.4)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (1.3.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (0.7.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (0.6.2)
# Requirement already satisfied: langchain_classic in /usr/local/lib/python3.12/dist-packages (1.0.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.5 in /usr/local/lib/python3.12/dist-packages (from langchain_classic) (1.2.12)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain_classic) (1.1.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from langchain_classic) (0.7.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain_classic) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain_classic) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain_classic) (2.32.4)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_classic) (2.0.46)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.5->langchain_classic) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.5->langchain_classic) (26.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.5->langchain_classic) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.5->langchain_classic) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.5->langchain_classic) (0.14.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain_classic) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain_classic) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain_classic) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain_classic) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain_classic) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain_classic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain_classic) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain_classic) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain_classic) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain_classic) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain_classic) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain_classic) (2026.1.4)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain_classic) (3.3.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain_classic) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain_classic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain_classic) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.5->langchain_classic) (3.0.0)

# %%
from google.colab import userdata
gem = userdata.get('Gemini')

import os
os.environ["GOOGLE_API_KEY"] =gem
# We have setuped the environment variable for accessing gemini models

# %%
import langchain
import langchain_classic #To access chain
# langchain_classic is used to support the old chain-based APIs like LLMChain and ConversationChain. It helps old projects keep working after LangChain was divided into smaller packages like langchain_core and langchain_community.

from langchain_google_genai import GoogleGenerativeAI, ChatGoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser # For Output Parser

# %% [markdown]
# ## Problem statement
#
# The main objective of this case study is to clearly understand and compare three different workflows in LangChain in an effective and practical way.
#
# To achieve this, we will build a simple LLM application that takes a story as input and generates 3 to 4 meaningful questions to test comprehension and thinking ability.

# %%
# Step 1 = Create a prompt template
from langchain_core.prompts import ChatPromptTemplate, HumanMessagePromptTemplate, SystemMessagePromptTemplate

# %%
runn1_cpt = ChatPromptTemplate.from_messages([SystemMessagePromptTemplate.from_template("You are having a 10 years of experience in writing and generating a story for children's"),
                                  HumanMessagePromptTemplate.from_template("Based on this genre: {genre} generate a story")])

# %%
# Step 2 = Set LLM Model
runn2_model = ChatGoogleGenerativeAI(model = "gemini-2.5-flash-lite")

# %%
# Step 3 = Create Output
runn3_strp = StrOutputParser()

# %% [markdown]
# ## Types of Runnables
#
# ### 1. Runnable Sequence

# %%
from langchain_core.runnables import RunnableSequence

# We import RunnableSequence from langchain_core.runnables to combine multiple steps (like prompt → model → output parser) into a single structured pipeline.

# It allows us to execute steps in sequence using the modern workflow design of LangChain, making the application more modular, clean, and scalable.

# %%
# Functions is like a runnables (Process[input] generate output)

# %%
sequential_chain = RunnableSequence(runn1_cpt,runn2_model,runn3_strp) # Another way to mension = runn1_cpt|runn2_model|runn3_strp

# %% [markdown]
# ### For one input variable = {"genre":"Adventure"}

# %%
response = sequential_chain.invoke({"genre":"Adventure"}) # Give input as dict only
# Runnable = Take Single Input --> Return Single Output
# If we want multiple output so for that we need to make dictionary.

# %%
print(response)
# Out:
# Barnaby Button was an adventurer. Not the kind who battled dragons or discovered lost cities, mind you. Barnaby's adventures were usually confined to the wild, untamed jungle of his own backyard.
#
# One sunny morning, a glint of something unusual caught Barnaby's eye near the ancient oak tree. It was a tiny, shimmering feather, unlike any he'd ever seen. It was the colour of a rainbow after a summer shower, with hints of emerald green and sapphire blue.
#
# "A treasure!" Barnaby whispered, his heart thumping with excitement. He carefully picked it up. It felt soft and strangely warm in his fingers. "This must belong to a very special bird!"
#
# His mission was clear: find the owner of the rainbow feather. He grabbed his trusty magnifying glass (essential for any serious explorer) and his trusty sidekick, a fluffy, ginger cat named Marmalade, who mostly enjoyed napping in sunbeams but occasionally batted at interesting bugs.
#
# Barnaby started his expedition at the base of the oak. He scanned the bark for clues, imagining tiny footprints or discarded seeds. Marmalade, meanwhile, was engrossed in a fierce battle with a dandelion puff.
#
# "Anything, Marmalade?" Barnaby asked, though he knew Marmalade was more interested in fluff than feathers. Marmalade responded with a lazy yawn.
#
# Undeterred, Barnaby ventured deeper into the "Emerald Jungle," as he called the overgrown rose bush. He pushed aside prickly branches, his eyes peeled for any sign of unusual colour. He imagined the bird to be shy, perhaps hiding amongst the dense foliage.
#
# Suddenly, a flash of iridescent colour zipped past his nose! Barnaby gasped. It was a tiny hummingbird, its wings a blur, hovering near a bright red fuchsia. It was too fast to get a good look, but Barnaby was sure he saw a hint of rainbow shimmer.
#
# "That's it!" he exclaimed. "The rainbow bird!"
#
# He followed the hummingbird, his heart pounding with anticipation. It flitted from flower to flower, a tiny jewel against the green. Barnaby, trying to be as quiet as a stalking tiger, crept along the garden path.
#
# The hummingbird led him to the far corner of the garden, where a small, bubbling bird bath stood. And there, perched on the edge, was the most magnificent bird Barnaby had ever seen. It was small, no bigger than his thumb, but its feathers shimmered with every colour imaginable. It dipped its beak into the water, and as it tilted its head, the sunlight caught its plumage, making it glow.
#
# Barnaby held his breath. He didn't want to scare it. He slowly, ever so slowly, reached into his pocket and pulled out the shimmering feather. He held it out, a silent offering.
#
# The rainbow bird turned its head, its bright, intelligent eyes meeting Barnaby's. It chirped a soft, melodious tune, a sound like tiny bells. Then, it hopped closer, took the feather from Barnaby's outstretched finger with its delicate beak, and tucked it neatly amongst its own dazzling feathers.
#
# Barnaby beamed. He had found the owner! The bird gave him one last, happy chirp, and then with a whir of its rainbow wings, it soared into the sky, a breathtaking streak of colour against the blue.
#
# Barnaby watched until it was just a tiny speck. He felt a warmth spread through him, a feeling of accomplishment and wonder. His backyard adventure had led him to something truly magical.
#
# He turned to Marmalade, who had finally decided the dandelion battle was over and was now grooming himself meticulously. "Marmalade," Barnaby announced, puffing out his chest, "we had a truly magnificent adventure today!"
#
# Marmalade blinked slowly, then nudged Barnaby's hand with his head, as if to say, "Yes, and now it's time for a nap."
#
# Barnaby chuckled. He knew that even if Marmalade didn't quite understand, his own heart was full of the joy of discovery. And he couldn't wait for his next adventure in the wild, untamed jungle of his backyard.

# %% [markdown]
# ### For 2 input variables = {"genre":"Adventure","years":10}

# %%
runn2_cpt = ChatPromptTemplate.from_messages([SystemMessagePromptTemplate.from_template("You are having a {years} years of experience in writing and generating a story for children's"),
                                  HumanMessagePromptTemplate.from_template("Based on this genre: {genre} generate a story")])

# %%
sequential_chain_2 = RunnableSequence(runn2_cpt,runn2_model,runn3_strp) # Another way to mension = runn2_cpt|runn2_model|runn3_strp

# %%
response_2 =sequential_chain_2.invoke({"genre":"Adventure","years":10})
# here we pass 2 inputs

# %%
print(response_2)
# Out:
# Barnaby Button was not your average ten-year-old. While other kids were busy with video games and soccer practice, Barnaby was busy with maps. Not just any maps, mind you. He collected them, traced them, and dreamed of the places they represented. His bedroom walls were a tapestry of ancient cartography, a testament to his burning desire for adventure.
#
# One rainy Tuesday, while rummaging through his grandfather’s dusty attic, Barnaby stumbled upon a peculiar rolled-up parchment tucked away in an old sea chest. It wasn't a map of any place he recognized. Instead, it was a series of intricate drawings, strange symbols, and a single, faded inscription in a language he couldn't decipher.
#
# "What in the world is this?" he muttered, his heart thrumming with a familiar excitement.
#
# He spent days poring over the parchment, comparing the symbols to ancient alphabets he found in his books. Finally, a breakthrough! The symbols weren't letters, but a code. And the inscription, once deciphered, read:
#
# "Where the Whispering Willow weeps, and the Sunstone sleeps, lies the entrance to the forgotten deep."
#
# The Whispering Willow! Barnaby knew that place. It was a massive, ancient willow tree in the heart of Blackwood Forest, a place whispered about in hushed tones by the townsfolk, a place said to be enchanted. And the Sunstone? He’d heard tales of a legendary gem, lost for centuries, rumored to glow with an inner light.
#
# His adventure had begun.
#
# The next morning, with a knapsack packed with essentials – a compass, a magnifying glass, a sturdy rope, and a very large sandwich – Barnaby set off for Blackwood Forest. The air grew cooler as he ventured deeper, the sunlight dappled through the thick canopy of leaves. The usual chirping of birds seemed to fade, replaced by an eerie silence.
#
# He found the Whispering Willow easily. Its branches, thick and gnarled, drooped like weeping arms, and a gentle breeze rustled its leaves, creating a soft, melancholic sigh. Barnaby scanned the ground around its trunk, searching for any sign of the Sunstone. He found nothing but moss and fallen leaves.
#
# Disappointed, he sat down, leaning against the ancient trunk. As he did, his hand brushed against a rough patch of bark. He looked closer. It was a carving, almost hidden by the moss, matching one of the symbols on his parchment!
#
# He traced the carving, his fingers following the lines. Suddenly, with a low groan, a section of the willow’s trunk swung inwards, revealing a dark, narrow opening.
#
# "The entrance to the forgotten deep!" Barnaby exclaimed, his eyes wide with wonder.
#
# He didn't hesitate. With a deep breath, he stepped into the darkness, his heart pounding a rhythm of pure adventure. The passage was damp and smelled of earth and ancient secrets. He used his compass to navigate, the beam of his flashlight cutting through the gloom.
#
# The passage led him to a vast cavern. Stalactites hung like icy teeth from the ceiling, and the air was thick with a strange, ethereal glow. In the center of the cavern, resting on a pedestal of smooth, dark stone, was a gem. It pulsed with a soft, warm light, just as the legends described. The Sunstone.
#
# But as Barnaby approached, a low growl echoed from the shadows. Two glowing eyes appeared, then another pair, and another. A pack of shadow wolves, their fur the color of midnight, emerged from the darkness, their fangs bared.
#
# Barnaby’s blood ran cold. He was trapped. He clutched his magnifying glass, his mind racing. He remembered a detail from one of his grandfather’s old books about legends of the forest: shadow wolves were creatures of darkness, and light was their weakness.
#
# He quickly unrolled his parchment. The symbols! He remembered another inscription he’d deciphered: "The Sunstone’s light, when amplified, repels the night."
#
# Barnaby grabbed the Sunstone. It was surprisingly warm in his hands. He held it up, its light shining brightly, but it wasn't enough. The wolves crept closer, their growls intensifying.
#
# Then, he had an idea. He remembered the magnifying glass in his knapsack. He pulled it out, positioning it between the Sunstone and the approaching wolves. He adjusted the angle, focusing the Sunstone’s light through the glass, creating a beam of intense, concentrated light.
#
# The wolves recoiled, yelping as the amplified light struck them. They couldn't bear it. With a final, mournful howl, they turned and melted back into the shadows from which they came.
#
# Barnaby let out a shaky breath, his legs feeling like jelly. He had done it. He had faced the creatures of the dark and emerged victorious, all thanks to his wits and a little bit of ancient magic.
#
# He carefully placed the Sunstone back on its pedestal. He knew it belonged there, a guardian of the forgotten deep. His adventure had been more than he could have ever imagined.
#
# As Barnaby made his way back through the passage, the Whispering Willow seemed to sigh a little louder, a sound of approval. Emerging into the dappled sunlight of Blackwood Forest, he felt a sense of accomplishment that no video game could ever provide. He was Barnaby Button, the boy who had followed a map of symbols, found a legendary gem, and outsmarted shadow wolves. And he knew, with a certainty that warmed him like the Sunstone itself, that this was just the beginning of his grand adventures.

# %%
# Whenever we are accessing a single model components (use invoke) dont need to pass dictionary as a variable data.
# But whenever we are using runnables sequence at that time, if we want to pass multiple input, then we use dictionary because it acts like this =
# sequential_chain_2.invoke(input = {"genre":"Adventure","years":10})

# %% [markdown]
# ### One condition :
#
# If we pass an extra variable like "x": 10 in :
# sequential_chain_2.invoke({"genre":"Adventure","years":10,"x":10})
# #### and "x" is not used in the prompt template, it will not give an error.
#
# - LangChain simply ignores the extra variable by default and only uses the variables that are defined in the prompt template.
#
# - So unused inputs are automatically skipped.

# %% [markdown]
# ## Problem statement:
#
# LLM Workflow:
#
# - Use the LLM to generate a story based on given inputs (e.g., genre, theme, years).
#
# - Pass the generated story as input to the same or another LLM.
#
# - The LLM analyzes the story and provides a rating (e.g., out of 10) based on quality, creativity, and coherence.
#
# Simple Flow:
# LLM → Generate Story → Pass Story → LLM → Give Rating

# %%
# chatpromptTemplate_1 --> LLM --> story --> outputparser --> story --> chatpromptTemplate_2 --> LLM --> ratings

# %%
# Create Prompt_Template for (creating a story)
cpt_1 = ChatPromptTemplate.from_messages([SystemMessagePromptTemplate.from_template("You are having a {years} years of experience in writing and generating a story for children's"),
                                  HumanMessagePromptTemplate.from_template("Based on this genre: {genre} generate a story")])

# Create Prompt_Template for (to generate ratings)
cpt_2 = ChatPromptTemplate.from_messages([SystemMessagePromptTemplate.from_template("You are having a 10 years of experience in giving ratings on a story"),
                                  HumanMessagePromptTemplate.from_template("Based on this story: {story} rate it out of 5 where 5 is the best and 1 is the worst ")])

# %%
# (years,genre) 2_input_variable-->ChatPromptTemplate[runn_cpt_1]:Prompt-->LLM--return[AI message]-->StringOutputParser-->Return[Text] NEXT👇
# Return[Text] go as -->(Story) 1_input_variable-->ChatPromptTemplate[runn_cpt_2]:Prompt-->LLM--return[AI message]-->StringOutputParser-->rating

# %%
from google.colab import userdata
gem_lite = userdata.get('gemini_lite')

import os
os.environ["GOOGLE_API_KEY"] =gem_lite
# We have setuped the environment variable for accessing gemini models

# %%
# Step 2 = Set LLM Model
model = ChatGoogleGenerativeAI(model = "gemini-2.5-flash-lite")

# %%
seq_chain_1 = cpt_1|model|runn3_strp|cpt_2|model|runn3_strp # Using Sequence Chain

# %%
response_rating = seq_chain_1.invoke({"years":20,"genre":"adventure"})

# %%
print(response_rating)
# Out:
# Here's my rating of the story "Barnaby Button":
#
# **Rating: 4.5 out of 5**
#
# **Reasoning for the rating:**
#
# This is a charming and well-crafted adventure story for young readers. Here's a breakdown of why it earns a high score:
#
# *   **Engaging Protagonist:** Barnaby is an instantly likable and relatable character. His imaginative nature and thirst for adventure make him the perfect hero for this kind of tale. The contrast with his peers is a nice touch that grounds him in childhood reality.
# *   **Magical Premise:** The discovery of the "Whispering Feather" is a classic and effective fantasy trope. The immediate transportation to the jungle is a great hook that propels the story forward with excitement.
# *   **Clear and Satisfying Plot Arc:** The story follows a classic adventure structure: discovery, journey, challenges, and reward. Each element is present and well-executed.
# *   **Creative Challenges:** The monkey encounter and the river crossing are age-appropriate and clever challenges that Barnaby overcomes through kindness and observation, reinforcing positive values.
# *   **Meaningful Treasure:** The "treasure" being ancient maps and explorer journals is a wonderful twist. It emphasizes the value of knowledge, imagination, and future adventures over material wealth, which is a beautiful message.
# *   **Strong Theme:** The overarching theme that "the greatest treasure was the journey itself" is beautifully conveyed and leaves a lasting, positive impression.
# *   **Vivid Imagery:** The descriptions of the jungle, the feather's glow, and the sunset are evocative and help the reader immerse themselves in Barnaby's world.
# *   **Satisfying Conclusion:** The ending feels earned and inspiring, clearly signaling that this is just the beginning of Barnaby's grand adventures.
#
# **Areas for slight improvement (why not a perfect 5):**
#
# *   **Pacing:** While generally good, the transition from the attic to the jungle is very abrupt. A slightly more gradual shift might add a touch more wonder.
# *   **Originality:** The core elements (magical artifact, jungle adventure, hidden treasure) are well-executed but lean on established fantasy tropes. While this isn't a bad thing for the target audience, a slightly more unique twist could elevate it further.
#
# Overall, this is a delightful story that sparks the imagination and delivers a heartwarming message. It's the kind of story that would be a joy to read aloud or for a young reader to discover independently.

# %%
runnable_sequence= RunnableSequence(cpt_1,model,runn3_strp,cpt_2,model,runn3_strp)

# %%
runnable_sequence.invoke({"years":20,"genre":"adventure"})

# Here cpt_2 automatically able to undersand (Entire output coming from [cpt_1,runn2_model,runn3_strp] chain) and giving to the variable {story})
# Because this entire chain is giving only one output that is a single text
# That's why we no need to pass story as an output
# Out:
# 'Here\'s my rating of Barnaby Button\'s adventure:\n\n**Rating: 4.5/5**\n\n**Reasoning (with 10 years of experience in mind):**\n\nThis is a truly delightful story with a lot of charm and potential. Here\'s a breakdown of why it earns a high rating:\n\n*   **Character Development (4.5/5):** Barnaby is immediately likeable. His description – "knobbly knees," "unruly ginger hair," and his backyard adventures – makes him relatable and endearing, especially to a younger audience. The story effectively establishes his yearning for adventure and his optimistic spirit, even when faced with minor setbacks. His Mum\'s gentle encouragement also adds a nice touch.\n\n*   **Plot and Pacing (4/5):** The plot unfolds at a good pace. The discovery of the locket is a strong hook, and the subsequent investigations at the oak tree and the well create a sense of mystery and anticipation. The resolution, while unexpected, is satisfying and fits the theme of the story. The story doesn\'t linger too long on any one element, keeping the reader engaged.\n\n*   **World-Building and Atmosphere (4.5/5):** Oakhaven feels like a classic, cozy village, providing a perfect contrast to Barnaby\'s burgeoning adventurous spirit. The "Whispering Woods" are described with just enough atmospheric detail to feel evocative without being overly scary. The well\'s description as "bottomless" and the ensuing magical elements are well-integrated.\n\n*   **Theme and Message (5/5):** This is where the story truly shines. The message that "adventure wasn\'t always about what you found, but about the journey, the mystery, and the magic that waited in the most unexpected places" is beautifully conveyed. The ending reinforces this perfectly, leaving the reader with a warm, hopeful feeling. The inscription "For those who seek wonder" is a perfect encapsulation of the story\'s core.\n\n*   **Originality and Creativity (4/5):** While the premise of a child finding a mysterious object and going on an adventure is common, the execution here is fresh. The locket as a "key" that doesn\'t unlock a physical door but leads to a magical encounter with a hummingbird is a creative twist. The gradual reveal of magic, rather than an immediate fantastical element, builds suspense effectively.\n\n*   **Writing Style and Language (4.5/5):** The prose is clear, engaging, and age-appropriate. The use of descriptive language ("knobbly knees," "tarnished brass locket," "iridescent glow") paints vivid pictures. The dialogue is natural, and Barnaby\'s internal thoughts feel authentic to a child\'s perspective.\n\n**Areas for slight improvement (which prevent a perfect 5/5):**\n\n*   **The "click" at the oak tree:** While it adds a moment of anticipation, it could have been slightly more impactful or led to a more tangible (even if small) clue to justify the locket\'s purpose there. However, its lack of a direct effect also serves to guide Barnaby to the well.\n*   **The well\'s wind:** The gust of wind that takes the locket feels a *tiny* bit like a convenient plot device. While it serves its purpose, a slightly more organic transition might have been even stronger.\n\n**Overall:**\n\nThis is a beautifully crafted children\'s story that captures the spirit of childhood wonder and the thrill of discovery. It’s the kind of story that stays with you, encouraging readers to look for magic in their own everyday lives. Barnaby is a character I\'d love to read more about. It\'s a strong 4.5 out of 5, a story I would happily recommend.'

# %%
# Use another LLM : runnablepassthorug

# %% [markdown]
# ### RunnablePassthrough = It is a primitive runnable in LangChain that simply returns the input as it is.
#
# 👉 It does not modify or process the data.
#
# 👉 Whatever input you give, it sends the same input as output.
#
# - In simple words:
# RunnablePassthrough = Input goes in → Same input comes out.

# %%
from langchain_core.runnables import RunnablePassthrough

# %%
rs =RunnablePassthrough()
# It return as output as input
# that input we can first assigned it to an another variable
# Input --> assigned [Variable]

# %%
# Example:
rs.invoke("2")
# Out:
# '2'

# %%
seq_chain_3 = RunnablePassthrough.assign(story = RunnableSequence(cpt_1,model,runn3_strp)) | cpt_2 | model | runn3_strp

# %% [markdown]
# - First, we generate the story.
#
# - Then, we use that same story in the next prompt (for rating, questions, etc.).
#
# - RunnablePassthrough.assign() helps us keep the original input and add the generated story to it.
#
# #### We do this to build a multi-step workflow where:
#
# Input → Story Generated → Story Used Again → Final Result
#
# - It helps us connect steps smoothly using the modern pipeline design of LangChain.

# %%
seq_chain_3.invoke({"years":20,"genre":"adventure"})
# Out:
# 'This is a delightful story with a lot of charm! Here\'s my rating based on my experience:\n\n**Rating: 4.5 out of 5**\n\nHere\'s a breakdown of why:\n\n**Strengths:**\n\n*   **Imaginative Protagonist:** Barnaby is a wonderfully conceived character. His passion for maps, especially unusual ones, is unique and engaging for a ten-year-old. This immediately sets him apart and makes him relatable to anyone who has had a strong, quirky interest.\n*   **Captivating Premise:** The "Whispering Isle" concept is immediately intriguing. The idea of a map leading to a place that communicates through sound is a fantastic hook.\n*   **Charming Sidekick:** Professor Wigglesworth is the perfect companion. His "portly" nature and talent for sniffing out snacks and trouble add humor and a touch of groundedness to Barnaby\'s fantastical quest. His "woof" of readiness is a great touch.\n*   **Well-Paced Adventure:** The story moves at a good pace. We get Barnaby\'s initial discovery, his persuasive approach to his parents (which is handled realistically and humorously), the exciting journey, and the eventual arrival and discovery on the island.\n*   **Evocative Descriptions:** The author does a great job of creating vivid imagery. Phrases like "old, crinkly, slightly-smelling-of-dust maps," "faded parchment," "swirling ocean, a jagged coastline," "dense, emerald-green jungle," and "moss that glowed with a soft, ethereal light" really bring the world to life.\n*   **Meaningful Resolution:** The "treasure" Barnaby finds isn\'t material wealth, but a deeper connection to nature and a sense of wonder. This is a beautiful and mature theme for a children\'s story. The "language of the island" is a lovely metaphor.\n*   **Satisfying Ending:** The journey home and Barnaby\'s changed perspective provide a strong sense of closure and anticipation for future adventures.\n\n**Areas for Minor Improvement (that prevent a perfect 5):**\n\n*   **Parental Agreement:** While the parents\' agreement is a necessary plot point, it feels *slightly* too easy. A little more gentle persuasion or a slightly more detailed negotiation might have added a touch more realism, even within the fantasy. However, for a story of this nature, it\'s a minor quibble.\n*   **The "Whispering":** While the concept is great, the actual "language" of the island is described as speaking of "peace, of growth, of the interconnectedness of all living things." This is lovely, but a *tiny* bit more specific detail about what the whispers *sounded* like, beyond a "soft, melodic humming," might have made the experience even more immersive. For example, were they like gentle chimes, rustling leaves in a specific rhythm, or something else?\n\n**Overall:**\n\nThis is a wonderfully crafted children\'s adventure story. It\'s imaginative, heartwarming, and has a positive message. Barnaby is a character readers will root for, and the Whispering Isle is a place they\'ll wish they could visit. It\'s a story that sparks imagination and celebrates the joy of discovery. I would happily recommend this!'

# %%
# Create Prompt_Template for (creating a story)
cpt_3 = ChatPromptTemplate.from_messages([SystemMessagePromptTemplate.from_template("You are having a {years} years of experience in writing and generating a story for children's"),
                                  HumanMessagePromptTemplate.from_template("Based on this genre: {genre} generate a story")])

# Create Prompt_Template for (to generate ratings)
cpt_4 = ChatPromptTemplate.from_messages([SystemMessagePromptTemplate.from_template("You are having a {exp} years of experience in giving ratings on a story"),
                                  HumanMessagePromptTemplate.from_template("Based on this story: {story} rate it out of 5 where 5 is the best and 1 is the worst ")])

# %%
sequential_chain_4 = RunnableSequence(cpt_3,model,runn3_strp,cpt_4,model,runn3_strp) # Another way to mension = runn2_cpt|runn2_model|runn3_strp
# cpt_3(years,genre) and cpt_4(exp,story) both having 2 inputes

# %%
seq_chain_4 = RunnablePassthrough.assign(story = RunnableSequence(cpt_3,model,runn3_strp))

# %%
response_4 = seq_chain_4.invoke({"years":20,"genre":"adventure"})

# %%
print(response_4)
# Out:
# {'years': 20, 'genre': 'adventure', 'story': "Barnaby Button loved adventure. Not the kind of adventure where you wrestle a dragon or discover a hidden treasure (though he wouldn't say no to that!). Barnaby's adventures were usually much smaller, and much more… ordinary.\n\nOne sunny Tuesday morning, Barnaby woke with a tingle in his toes. Today, he declared to his teddy bear, Professor Snuggles, was the day he would conquer the Great Unknown. The Great Unknown, in Barnaby's world, was the mysterious patch of overgrown weeds at the very back of his garden, a place his mum always told him to stay away from.\n\nHe pulled on his trusty explorer boots (wellington boots, really) and his brave knight helmet (a colander). Professor Snuggles, tucked safely into Barnaby's backpack, gave a silent nod of encouragement.\n\nCreeping out the back door, Barnaby surveyed his mission. The Great Unknown loomed before him, a jungle of towering dandelions and whispering grass. His heart thumped like a drum. What wonders lay hidden within?\n\nWith a deep breath, Barnaby plunged in. The grass tickled his knees, and the leaves rustled like secrets. He imagined himself a mighty explorer, hacking through dense foliage with his trusty stick-sword.\n\nSuddenly, he heard a tiny squeak! Barnaby froze. Was it a fearsome beast? He cautiously parted a giant dandelion leaf.\n\nThere, nestled amongst the roots, was a tiny, fluffy creature. It had big, curious eyes and wobbly legs. It was a baby bunny!\n\nThe bunny looked just as surprised to see Barnaby as Barnaby was to see it. It twitched its nose and then, with a hop, disappeared into the undergrowth.\n\nBarnaby's adventure had just gotten more exciting. He decided he had to find the bunny's mama. He followed the faint rustling sounds, his explorer senses tingling. He discovered a shimmering ladybug, its shell like a polished ruby. He saw a busy ant carrying a crumb twice its size, a miniature strongman. He even found a patch of the brightest bluebells he'd ever seen, like tiny bells waiting to be rung.\n\nAfter what felt like hours, Barnaby heard a soft thumping sound. He crept closer and peeked through a thicket of brambles. And there, by a large, mossy stone, was a mother rabbit, her ears twitching, and beside her, a little ball of fluff – the baby bunny he'd seen!\n\nBarnaby watched, a huge smile spreading across his face. He had found the lost bunny and helped it find its way home. His adventure in the Great Unknown was a success!\n\nAs the sun began to dip below the garden fence, Barnaby emerged from the weeds, his boots a little muddy and his colander helmet slightly askew. He felt like a true adventurer, having discovered not dragons or gold, but the wonder of the natural world right in his own backyard. And for Barnaby Button, that was the best kind of adventure of all."}

# %%
RunnablePassthrough.assign(exp =lambda response:response_4["years"])
# Out:
# RunnableAssign(mapper={
#   exp: RunnableLambda(lambda response: response_4['years'])
# })

# %%
from google.colab import userdata
gemini = userdata.get('gemini')

import os
os.environ["GOOGLE_API_KEY"] =gemini

# %%
model = ChatGoogleGenerativeAI(model = "gemini-2.5-flash-lite")

# %%
seq_chain_5 = RunnablePassthrough.assign(story = RunnableSequence(cpt_3,model,runn3_strp)) | RunnablePassthrough.assign(exp =lambda response:response_4["years"])

# %%
response_5 = seq_chain_5.invoke({"years":20,"genre":"adventure"})

# %%
response_5
# Out:
# {'years': 20,
#  'genre': 'adventure',
#  'story': 'Barnaby Button, a boy with knees perpetually smudged with dirt and a heart that thumped like a hummingbird\'s wings, lived in a town that was, to put it mildly, rather ordinary. The most exciting thing that happened was when Mrs. Higgins\' cat, Bartholomew, got stuck up the oak tree for the third time that month. But Barnaby dreamed of more. He dreamed of hidden treasures, of roaring beasts, and of lands painted with colors no one had ever seen.\n\nOne sun-drenched afternoon, while exploring the dusty attic of his grandmother’s house, Barnaby stumbled upon an old, leather-bound book. Its pages were brittle, and the ink had faded to a whisper, but the title, etched in gold that still gleamed faintly, read: "The Chronicles of the Whispering Isles."\n\nAs Barnaby opened the book, a gust of wind, smelling of salt and something sweet like mangoes, swept through the attic, though all the windows were shut tight. The pages began to shimmer, and the words rearranged themselves, forming a map. It wasn\'t a map of his town, or even his country. It was a map of islands, strange shapes floating on a swirling blue sea. And in the center, a giant, glittering X.\n\nHis heart did a triple somersault. This was it! An adventure!\n\nThe map showed a starting point: the "Gnarled Oak of Sighs," a tree he knew well from the edge of the Whispering Woods, a place his mother always told him not to wander too far into. Clutching the book, Barnaby scrambled down from the attic, his ordinary world suddenly feeling a little less ordinary.\n\nHe packed a rucksack with a half-eaten apple, a compass his grandfather had given him (though he wasn’t entirely sure how to use it), and a sturdy stick he’d named "Sir Reginald." He slipped out of the house, the sun still high in the sky, and headed towards the Whispering Woods.\n\nThe woods were usually a place of dappled sunlight and bird songs. But today, as he approached the Gnarled Oak, the air grew still. The leaves seemed to hold their breath. The oak itself was ancient, its branches twisted like arthritic fingers.\n\nFollowing the map, Barnaby found a small, moss-covered stone at the base of the tree. He pressed it, and to his astonishment, the stone sank inwards with a soft *click*. A hidden passage, cloaked in ivy, opened before him. It smelled of damp earth and something faintly metallic, like old coins.\n\nTaking a deep breath and gripping Sir Reginald, Barnaby stepped inside. The passage was dark, but a faint, phosphorescent glow emanated from the walls, guiding his way. He walked for what felt like hours, the only sound the echo of his own footsteps and the occasional drip of water.\n\nSuddenly, the passage opened into a vast cavern. The air here was warm and humid, and the walls sparkled with embedded crystals. In the center of the cavern, a shimmering portal pulsed with an otherworldly light. It looked like a doorway made of rainbows.\n\nThe map in the book now pointed directly at the portal. This was the gateway to the Whispering Isles. With a surge of excitement that made his toes tingle, Barnaby stepped through.\n\nHe blinked, his eyes adjusting to a blindingly bright, tropical sun. He was standing on a beach of sand so white it looked like powdered sugar. The sea was an impossible shade of turquoise, and strange, colorful birds with feathers like jewels flitted through the air, singing melodies he’d never heard.\n\nThis was the first of the Whispering Isles!\n\nHis map now showed a path leading inland, past a grove of trees that bore fruit shaped like tiny, glowing lanterns. As he walked, he heard a rustling in the bushes. His heart leaped into his throat. Was it a roaring beast?\n\nOut popped a creature unlike anything he’d ever imagined. It was small, furry, and had large, curious eyes. It also had six legs and a tail that wagged like a happy puppy’s. It chirped at him, a sound like tiny bells.\n\nBarnaby, remembering his manners, bowed slightly. "Hello," he said. "I\'m Barnaby Button ...
#  'exp': 20}

# %%
print(response_5.keys())
# Out:
# dict_keys(['years', 'genre', 'story', 'exp'])

# %%
Final_chain = RunnablePassthrough.assign(story=RunnableSequence(cpt_3,model,runn3_strp)) | RunnablePassthrough.assign(exp = lambda response:response_4["years"]) | RunnableSequence(cpt_4,model,runn3_strp)

# %%
Final_response = Final_chain.invoke({"years":20,"genre":"adventure"})

# %%
print(Final_response)
# Out:
# As an experienced reviewer of stories, I've had the pleasure of delving into countless narratives. Barnaby Button's adventure in the Whispering Woods is a charming and well-crafted tale that taps into the pure magic of childhood imagination.
#
# Here's my rating and breakdown:
#
# **Rating: 4.5 out of 5**
#
# **Breakdown:**
#
# *   **Concept and Imagination (5/5):** The core concept of "Adventure Boots" and the "Whispering Woods" is brilliant. It perfectly captures the essence of a child's boundless imagination and their ability to transform the mundane into the extraordinary. The way Barnaby's backyard becomes a portal to a magical realm is beautifully depicted.
# *   **Character Development (4/5):** Barnaby is an endearing protagonist. His unwavering belief in his Adventure Boots and his patient teddy bear, Professor Snuggles, makes him instantly likable. While Professor Snuggles is a silent companion, his presence adds to Barnaby's world. The Guardian of the Woods serves its purpose effectively as a guide and dispenser of wisdom.
# *   **World-Building (4.5/5):** The Whispering Woods are brought to life with vivid imagery. The descriptions of the fantastical trees, the unique flower colors, and the "sleeping giants" moss-covered rocks create a rich and immersive environment. The anthropomorphized elements like the chattering squirrels and the silent butterfly add to the enchantment.
# *   **Plot and Pacing (4/5):** The story follows a classic adventure structure: a call to action, a journey, a discovery, and a return. The pacing is good, allowing the reader to soak in the magical atmosphere without feeling rushed. The discovery of the Stone of Whispers and its subsequent revelation of the "secrets of the forest" is a satisfying climax.
# *   **Theme and Message (5/5):** The overarching theme of listening to the world around you and finding adventure in the ordinary is a powerful and valuable message. The story subtly teaches the importance of observation, imagination, and the hidden wonders that exist if we just take the time to notice them. The idea that Barnaby keeps his adventure as a personal treasure is also a lovely touch.
# *   **Writing Style and Tone (4.5/5):** The language is accessible and evocative, perfectly suited for a children's story. The tone is consistently whimsical and optimistic. The use of sensory details, like the crunch of the boots on the grass and the pulsing warmth of the stone, enhances the reader's experience.
#
# **What makes it a strong 4.5?**
#
# The story excels in its pure, unadulterated sense of wonder. It doesn't try to be overly complex; instead, it focuses on the magic of a child's mind and the simple joy of exploration. The "whispers" of the world are a beautifully metaphorical treasure, far more valuable than any material wealth.
#
# **Could it be a 5?**
#
# While excellent, a tiny bit more might have pushed it to a perfect score. Perhaps a slightly more active role for Professor Snuggles, or a more tangible interaction with the Guardian, could have added an extra layer. However, these are minor points in an otherwise delightful narrative.
#
# **In conclusion:** Barnaby Button's journey is a testament to the power of imagination. It's a story that will resonate with young readers and remind adults of the magic they might have forgotten. A truly delightful read!

# %%
Final_dict_output= RunnablePassthrough.assign(story=RunnableSequence(cpt_3,model,runn3_strp)) | RunnablePassthrough.assign(exp = lambda response:response_4["years"]) | RunnablePassthrough.assign(output = cpt_4 | model | runn3_strp)

# %%
dict_Final_output = Final_dict_output.invoke({"years":20,"genre":"adventure"})

# %%
dict_Final_output.keys()
# Out:
# dict_keys(['years', 'genre', 'story', 'exp', 'output'])

# %%
dict_Final_output
# Out:
# {'years': 20,
#  'genre': 'adventure',
#  'story': '## The Whispering Waterfall and the Lost Locket\n\nBarnaby Button was a boy whose pockets always seemed to be full of interesting things: smooth grey pebbles, a particularly shiny beetle wing, and sometimes, if he was lucky, a forgotten jellybean. Barnaby loved adventures, the kind that started with a hunch and ended with a discovery.\n\nOne sunny afternoon, while exploring the edge of the Whispering Woods, Barnaby heard a faint, tinkling sound. It was like tiny bells dancing on the wind, but it wasn\'t coming from the trees. He followed the sound, pushing aside ferns as tall as his shoulders, his heart thumping with that familiar thrill of the unknown.\n\nThe tinkling grew louder, leading him deeper into the woods until he stumbled upon a small, moss-covered clearing. In the center, a tiny waterfall, no bigger than his outstretched arms, cascaded down smooth, grey rocks. And there, tangled in the delicate spray, was a beautiful, heart-shaped locket, glinting like a fallen star.\n\nBarnaby carefully reached out and plucked the locket from the water. It was made of a silvery metal, and etched onto its surface was a tiny, intricate picture of a soaring bird. When he opened it, he found not a picture of a person, but a miniature map, drawn with faint, shimmering ink. The map showed a winding path, marked with little drawings of acorns and mushrooms, leading to a place labeled with a single, sparkling dewdrop.\n\n"Wow!" Barnaby breathed, his eyes wide. This was an adventure! He knew he had to find out who the locket belonged to. He tucked the locket safely into his pocket, the tiny map now etched in his memory.\n\nThe next morning, with a packed lunch of cheese sandwiches and a bottle of fizzy lemonade, Barnaby set off. He followed the path from the locket’s map, his trusty compass (a gift from his Grandpa, who also loved adventures) pointing the way. He passed trees that looked like grumpy old men and bushes that whispered secrets as he brushed by them. He saw squirrels burying nuts with such serious faces, he almost asked them if they were planning a heist.\n\nAfter a long walk, the path led him to a clearing even more beautiful than the one with the waterfall. Wildflowers bloomed in every color imaginable, and the air hummed with the buzz of happy bees. In the very center of the clearing, resting on a bed of softest moss, was a small, wooden birdhouse, painted in the same silvery color as the locket.\n\nBarnaby approached cautiously. He didn\'t want to scare anyone. He held up the locket. "Hello?" he called out softly.\n\nSuddenly, a tiny, fluttery sound came from inside the birdhouse. The little wooden door creaked open, and out hopped a robin, no bigger than Barnaby’s thumb. But this robin was no ordinary bird. It had a tiny, shimmering feather tucked behind its ear, and its eyes twinkled with intelligence.\n\n"Oh, thank goodness!" chirped the robin, its voice like the tinkling of bells. "You found it! I thought it was lost forever!"\n\nBarnaby was so surprised, he almost dropped his lemonade. "You... you can talk?"\n\nThe robin bobbed its head. "Of course! My name is Pip. And that locket belonged to my grandmother. She lost it when she was trying to show me the way to the Crystal Cave, a place full of the most beautiful, sparkling dewdrop flowers."\n\nBarnaby’s heart leaped. "The dewdrop! I saw it on the map!"\n\nPip hopped excitedly. "Oh, you\'re the one! My grandmother always said the locket would lead a kind soul to the cave. Would you like to see it?"\n\nBarnaby nodded eagerly. Pip, with a flap of its tiny wings, took to the air, Barnaby following on foot, guided by the memory of the locket\'s map. They squeezed through narrow passages, climbed over smooth, round stones, and finally, they emerged into a cavern that shimmered with a thousand tiny lights.\n\nAnd there, all around them, were the most beautiful flowers Barnaby had ever seen. They were like tiny, perfect dewdrops, each one glowing with its own soft ...
#  'exp': 20,
#  'output': 'With 20 years of experience in evaluating stories, I\'d rate "The Whispering Waterfall and the Lost Locket" a solid **4 out of 5 stars**.\n\nHere\'s my breakdown:\n\n**Strengths:**\n\n*   **Charming Protagonist:** Barnaby Button is an immediately likable character. His love for "interesting things" and his innate sense of adventure make him relatable and engaging, especially for a younger audience. His curiosity is the perfect engine for the plot.\n*   **Evocative Setting:** The descriptions of the Whispering Woods, the tiny waterfall, and especially the final clearing with the dewdrop flowers are beautifully rendered. They create a sense of wonder and magic that draws the reader in.\n*   **Intriguing Mystery:** The discovery of the locket with its map is a classic and effective hook. It immediately sets up a quest and fuels Barnaby\'s desire for discovery.\n*   **Magical Element:** The talking robin, Pip, is a delightful and unexpected twist. It elevates the story beyond a simple treasure hunt into a more fantastical realm, and the interaction between Barnaby and Pip is heartwarming.\n*   **Satisfying Resolution:** The discovery of the Crystal Cave and the "dewdrop flowers" provides a visually stunning and emotionally rewarding conclusion. The theme of kindness leading to discovery is also a positive message.\n*   **Pacing:** The story moves at a good pace, with the initial discovery leading smoothly into the adventure, and the journey to the cave feeling well-developed without dragging.\n\n**Areas for Potential Improvement (Minor Points):**\n\n*   **Predictability:** While charming, the core "lost item leads to a magical discovery" trope is quite familiar. A slightly more unique twist on the map or the nature of the treasure could have pushed it to a 5.\n*   **Depth of Character:** While Barnaby is likable, his character arc is relatively simple. More internal reflection or a moment of doubt could have added another layer. Similarly, Pip, while charming, is primarily a plot device.\n\n**Overall:**\n\nThis is a delightful and well-crafted short story. It successfully blends adventure, mystery, and a touch of magic, creating an experience that is both engaging and heartwarming. It would be particularly enjoyable for younger readers, but its evocative language and satisfying conclusion can be appreciated by all ages. The story fulfills its promise of adventure and leaves the reader with a sense of wonder. It\'s a strong 4-star tale that comes very close to perfection.'}
